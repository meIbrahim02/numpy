# %%
import numpy as np

# %%
#complex numbers
#complex64
#complex128
arr4 = np.array([3 + 5j])
arr5 = np.array([2 + 3j])

print(arr4, arr4.dtype)
print(arr4 + arr5) 
print(arr4 - arr5)
# Out:
# [3.+5.j] complex128
# [5.+8.j]
# [1.+2.j]
