# %%
import numpy as np

# %%
#string -> not advisable to use in numpy
# S -> (byte-str) & U -> (unicode-str)
arr3 = np.array([1,2,3,4,5,"hello"])
print(arr3, arr3.dtype)
# Out:
# ['1' '2' '3' '4' '5' 'hello'] <U21
