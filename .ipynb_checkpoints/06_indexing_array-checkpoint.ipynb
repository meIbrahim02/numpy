# %%
import numpy as np

# %%
# 1D array
arr = np.array([1,2,3,4,5])
print(arr[0])
print(arr[3])
# Out:
# 1
# 4

# %%
# 2D array
arr2 = np.array([[1,2,3,4],[5,6,7,8]])
print(arr2[0][2])
print(arr2[1][3])
# Out:
# 3
# 8
